# %%
# q1_1
# !python3 segment.py 0.8 300 20 ./data/imgs/190.png ./out/q1/q1_1_190.jpg
# !python3 segment.py 0.8 300 20 ./data/imgs/290.png ./out/q1/q1_1_290.jpg
# !python3 segment.py 0.8 200 20 ./data/imgs/390.png ./out/q1/q1_1_390.jpg
# !python3 segment.py 0.8 300 20 ./data/imgs/490.png ./out/q1/q1_1_490.jpg
# !python3 segment.py 0.8 300 20 ./data/imgs/590.png ./out/q1/q1_1_590.jpg
# !python3 segment.py 0.8 400 20 ./data/imgs/690.png ./out/q1/q1_1_690.jpg
# !python3 segment.py 0.8 300 20 ./data/imgs/790.png ./out/q1/q1_1_790.jpg
# !python3 segment.py 0.8 300 20 ./data/imgs/890.png ./out/q1/q1_1_890.jpg
# !python3 segment.py 0.8 200 20 ./data/imgs/990.png ./out/q1/q1_1_990.jpg
# Out:
# 区域数： 64
# 区域数： 99
# 区域数： 63
# 区域数： 91
# 区域数： 82
# 区域数： 87
# 区域数： 60
# 区域数： 65
# 区域数： 52

# %%
# q1_2
# !python3 mark_segment.py 0.8 300 20 ./data/imgs/190.png ./out/q1/q1_2_190.jpg ./data/gt/190.png
# !python3 mark_segment.py 0.8 300 20 ./data/imgs/290.png ./out/q1/q1_2_290.jpg ./data/gt/290.png
# !python3 mark_segment.py 0.8 200 20 ./data/imgs/390.png ./out/q1/q1_2_390.jpg ./data/gt/390.png
# !python3 mark_segment.py 0.8 300 20 ./data/imgs/490.png ./out/q1/q1_2_490.jpg ./data/gt/490.png
# !python3 mark_segment.py 0.8 300 20 ./data/imgs/590.png ./out/q1/q1_2_590.jpg ./data/gt/590.png
# !python3 mark_segment.py 0.8 400 20 ./data/imgs/690.png ./out/q1/q1_2_690.jpg ./data/gt/690.png
# !python3 mark_segment.py 0.8 300 20 ./data/imgs/790.png ./out/q1/q1_2_790.jpg ./data/gt/790.png
# !python3 mark_segment.py 0.8 300 20 ./data/imgs/890.png ./out/q1/q1_2_890.jpg ./data/gt/890.png
# !python3 mark_segment.py 0.8 200 20 ./data/imgs/990.png ./out/q1/q1_2_990.jpg ./data/gt/990.png
# Out:
# 区域数： 64
# 区域数： 99
# 区域数： 63
# 区域数： 91
# 区域数： 82
# 区域数： 87
# 区域数： 60
# 区域数： 65
# 区域数： 52

# %%
# q2
# !python3 q2.py 10
# Out:
# finish training image: 101 区域数 64
# finish training image: 102 区域数 63
# finish training image: 103 区域数 43
# finish training image: 104 区域数 84
# finish training image: 105 区域数 76
# finish training image: 106 区域数 34
# finish training image: 107 区域数 61
# finish training image: 108 区域数 56
# finish training image: 109 区域数 99
# predict image ./data/imgs/90.png acc:  0.47540983606557374
# predict image ./data/imgs/190.png acc:  0.359375
# predict image ./data/imgs/290.png acc:  0.16161616161616163
# predict image ./data/imgs/390.png acc:  0.38636363636363635
# predict image ./data/imgs/490.png acc:  0.27472527472527475
# predict image ./data/imgs/590.png acc:  0.2682926829268293
# predict image ./data/imgs/690.png acc:  0.5098039215686274
# predict image ./data/imgs/790.png acc:  0.13333333333333333
# predict image ./data/imgs/890.png acc:  0.23076923076923078
# predict image ./data/imgs/990.png acc:  0.16216216216216217

# %%
# q2
# !python3 q2.py 100
# Out:
# finish training image: 201 区域数 37
# finish training image: 202 区域数 52
# finish training image: 203 区域数 47
# finish training image: 204 区域数 58
# finish training image: 205 区域数 124
# finish training image: 206 区域数 86
# finish training image: 207 区域数 64
# finish training image: 208 区域数 59
# finish training image: 209 区域数 69
# finish training image: 210 区域数 64
# finish training image: 211 区域数 52
# finish training image: 212 区域数 19
# finish training image: 213 区域数 42
# finish training image: 214 区域数 50
# finish training image: 215 区域数 65
# finish training image: 216 区域数 59
# finish training image: 217 区域数 65
# finish training image: 218 区域数 49
# finish training image: 219 区域数 66
# finish training image: 220 区域数 44
# finish training image: 221 区域数 62
# finish training image: 222 区域数 73
# finish training image: 223 区域数 47
# finish training image: 224 区域数 49
# finish training image: 225 区域数 81
# finish training image: 226 区域数 80
# finish training image: 227 区域数 46
# ...

# %%
# q3
# !python3 q3.py
# Out:
# --------------Image ./data/imgs/90.png ----------------
# [ WARN:0] global /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-yvyj7qlp/opencv_contrib/modules/xfeatures2d/misc/python/shadow_sift.hpp (15) SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736
# cluster 1 , include  85 patches
# image cluster 0 saved
# cluster 2 , include  121 patches
# image cluster 1 saved
# cluster 3 , include  83 patches
# image cluster 2 saved
# --------------Image ./data/imgs/190.png ----------------
# cluster 1 , include  155 patches
# image cluster 0 saved
# cluster 2 , include  146 patches
# image cluster 1 saved
# cluster 3 , include  53 patches
# image cluster 2 saved
# --------------Image ./data/imgs/290.png ----------------
# cluster 1 , include  198 patches
# image cluster 0 saved
# cluster 2 , include  82 patches
# image cluster 1 saved
# cluster 3 , include  180 patches
# ...
